# %% [markdown]
# # Statsbomb API
#
# Statsbomb has a public API where they have released event data from a lot of different leagues, matches, and seasons. They also have their Statsbomb360 Data which is a hybrid of tracking data and event data. It bascially allows you to get more information about event data and where other players are on the field at the time of the event.
#
# For example, you can get data from the past couple of world cups, Euros, they even have all the data from every match Messi has played in.
#
# We will be primarily using the Statsbomb API in the visualizations section & data analysis section of this course.
#
# Statsbomb makes it a little bit difficult at first to find the data we need mainly because you need to know the competition_id and the season_id to get the data you want.

# %%
from statsbombpy import sb

# %%
# Load all competitions
sb.competitions()

# Take note of the competition_id and season_id
# Out:
# /Users/mckayjohns/miniforge3/envs/complete-football-analytics/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name        competition_name  \
# 0                9         27        Germany           1. Bundesliga
# 1             1267        107         Africa  African Cup of Nations
# 2               16          4         Europe        Champions League
# 3               16          1         Europe        Champions League
# 4               16          2         Europe        Champions League
# ..             ...        ...            ...                     ...
# 66              55         43         Europe               UEFA Euro
# 67              35         75         Europe      UEFA Europa League
# 68              53        106         Europe       UEFA Women's Euro
# 69              72        107  International       Women's World Cup
# ...

# %%
# Lets get more information about the recent African Cup of Nations
sb.matches(competition_id=1267, season_id=107)

# Take note of the match_id
# Out:
# /Users/mckayjohns/miniforge3/envs/complete-football-analytics/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off                      competition  \
# 0    3923881  2024-02-11  22:00:00.000  Africa - African Cup of Nations
# 1    3923880  2024-02-10  22:00:00.000  Africa - African Cup of Nations
# 2    3922838  2024-02-07  22:00:00.000  Africa - African Cup of Nations
# 3    3922837  2024-02-07  19:00:00.000  Africa - African Cup of Nations
# 4    3922242  2024-01-29  22:00:00.000  Africa - African Cup of Nations
# 5    3922239  2024-01-28  19:00:00.000  Africa - African Cup of Nations
# 6    3922659  2024-02-03  19:00:00.000  Africa - African Cup of Nations
# 7    3922658  2024-02-03  22:00:00.000  Africa - African Cup of Nations
# 8    3922244  2024-01-30  19:00:00.000  Africa - African Cup of Nations
# ...

# %%
# We can get one match like this:
sb.events(match_id=3923881).head(10)
# Out:
# /Users/mckayjohns/miniforge3/envs/complete-football-analytics/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
# 5   NaN                NaN                  NaN                     NaN
# 6   NaN                NaN                  NaN                     NaN
# 7   NaN                NaN                  NaN                     NaN
# 8   NaN                NaN                  NaN                     NaN
# ...

# %%
# If we wanted to get all the matches we need to loop through the match_ids
all_matches = []
for match_id in sb.matches(competition_id=1267, season_id=107).match_id:
    temp_match = sb.events(match_id=match_id)
    all_matches.append(temp_match)
# Out:
# /Users/mckayjohns/miniforge3/envs/complete-football-analytics/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/mckayjohns/miniforge3/envs/complete-football-analytics/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/mckayjohns/miniforge3/envs/complete-football-analytics/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# /Users/mckayjohns/miniforge3/envs/complete-football-analytics/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# ...

# %%
# Then we can concatenate all the matches into one dataframe
import pandas as pd
df = pd.concat(all_matches)

# %% [markdown]
# ##### A couple of notes:
# - You probably won't need to get all of the data from all of the matches unless you are doing larger analysis on a specific team or player.
# - The statsbomb api can be somewhat slow fetching all of the data and if you are gathering a lot of data you might end up with a large dataframe
# - You can use filtering to get just the data for a specific player you want to analyze for example:

# %%
df.player.unique()
# Out:
# array([nan, 'Ademola Lookman', 'William Troost-Ekong',
#        'Calvin Bassey Ughelumba', 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#        'Yahia Fofana', 'Obite Evan Ndicka', 'Ghislain Konan',
#        'Odilon Kossonou', 'Simon Adingra', 'Zaidu Sanusi', 'Alex Iwobi',
#        'Victor James Osimhen', 'Samuel Chimerenka Chukwueze',
#        'Temitayo Olufisayo Olaoluwa Aina', 'Frank Onyeka',
#        'Jean Michaël Seri', 'Serge Aurier', 'Stanley Bobo Nwabali',
#        'Seko Fofana', 'Max-Alain Gradel', 'Franck Yannick Kessié',
#        'Sébastien Haller', 'Moses Daddy-Ajala Simon',
#        'Wilfried Stephane Singo', 'Oumar Diakité',
#        'Kelechi Promise Iheanacho', 'Alhassan Yusuf', 'Joe Aribo',
#        'Ibrahim Sangaré', 'Terem Igobor Moffi', 'Jean-Philippe Krasso',
#        'Jean Thierry Lazare Amani', 'Grady Diangana',
#        'Samuel Moutoussamy', 'Khuliso Johnson Mudau',
#        'Simon Bokote Banza', 'Nkosinathi Sibisi', 'Ronwen Williams',
# ...

# %%
df = df[df['player'] == 'Victor James Osimhen'] # Now we only have data for Victor Osimhen

# %%
df.head()
# Out:
#     50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 22    NaN                NaN                  NaN                     NaN
# 91    NaN                NaN                  NaN                     NaN
# 156   NaN                NaN                  NaN                     NaN
# 158   NaN                NaN                  NaN                     NaN
# 461   NaN                NaN                  NaN                     NaN
#
#     ball_recovery_recovery_failure block_offensive carry_end_location  \
# 22                             NaN             NaN                NaN
# 91                             NaN             NaN                NaN
# 156                            NaN             NaN                NaN
# 158                            NaN             NaN                NaN
# 461                            NaN             NaN                NaN
#
#     clearance_aerial_won clearance_body_part clearance_head  ...  \
# ...
